# %%
! pip install kaggle
# !sudo apt install tesseract-ocr
# !pip install pytesseract
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.5.16)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kaggle) (2023.11.17)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle) (4.66.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.0.7)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle) (6.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.6)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 24 not upgraded.
# Need to get 4,816 kB of archives.
# After this operation, 15.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-eng all 1:4.00~git30-7274cfa-1.1 [1,591 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-osd all 1:4.00~git30-7274cfa-1.1 [2,990 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr amd64 4.1.1-2.1build1 [236 kB]
# Fetched 4,816 kB in 0s (12.6 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 3.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package tesseract-ocr-eng.
# (Reading database ... 121658 files and directories currently installed.)
# Preparing to unpack .../tesseract-ocr-eng_1%3a4.00~git30-7274cfa-1.1_all.deb ...
# Unpacking tesseract-ocr-eng (1:4.00~git30-7274cfa-1.1) ...
# Selecting previously unselected package tesseract-ocr-osd.
# Preparing to unpack .../tesseract-ocr-osd_1%3a4.00~git30-7274cfa-1.1_all.deb ...
# Unpacking tesseract-ocr-osd (1:4.00~git30-7274cfa-1.1) ...
# Selecting previously unselected package tesseract-ocr.
# Preparing to unpack .../tesseract-ocr_4.1.1-2.1build1_amd64.deb ...
# Unpacking tesseract-ocr (4.1.1-2.1build1) ...
# Setting up tesseract-ocr-eng (1:4.00~git30-7274cfa-1.1) ...
# Setting up tesseract-ocr-osd (1:4.00~git30-7274cfa-1.1) ...
# Setting up tesseract-ocr (4.1.1-2.1build1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Collecting pytesseract
#   Downloading pytesseract-0.3.10-py3-none-any.whl (14 kB)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from pytesseract) (23.2)
# Requirement already satisfied: Pillow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from pytesseract) (9.4.0)
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.10

# %% [markdown]
# Libraries Installation. Google Colab may encounter issues & not properly include Kaggle from the start. We have to install pytesseract and properly link it to our project.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Link your Google Drive to the Colab

# %%
! mkdir ~/.kaggle

# %%
# !cp /content/drive/MyDrive/kaggle.json ~/.kaggle/kaggle.json

# %% [markdown]
# Copy your Kaggle credentials, they are stored inside the kaggle.json

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
import os

folder_path = "/content/drive/MyDrive/car-plate-detection"

if not os.path.exists(folder_path):
    # !kaggle datasets download andrewmvd/car-plate-detection
    # !mkdir "/content/drive/MyDrive/car-plate-detection"
    # !unzip "/content/car-plate-detection.zip" -d "/content/drive/MyDrive/car-plate-detection"

# %% [markdown]
# Download the dataset & de-compress it

# %%
import cv2
import numpy as np
import pandas as pd
import tensorflow as tf
import pytesseract as pt
import plotly.express as px
import matplotlib.pyplot as plt
import xml.etree.ElementTree as xet

from glob import glob
from skimage import io
from shutil import copy
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import TensorBoard
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import InceptionResNetV2
from tensorflow.keras.layers import Dense, Dropout, Flatten, Input
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# %% [markdown]
# Import every library we will use for the model construction & training.
# - Glob processes large chunks of raw data
# - skimage processes pictures
# - tensorflow trains the Model
# - matplotlib displays results
# - pandas & numpy handle the filepaths & characteristics

# %%
path = glob('/content/drive/MyDrive/car-plate-detection/annotations/*.xml')
labels_dict = dict(filepath=[],xmin=[],xmax=[],ymin=[],ymax=[])
for filename in path:

    info = xet.parse(filename)
    root = info.getroot()
    member_object = root.find('object')
    labels_info = member_object.find('bndbox')
    xmin = int(labels_info.find('xmin').text)
    xmax = int(labels_info.find('xmax').text)
    ymin = int(labels_info.find('ymin').text)
    ymax = int(labels_info.find('ymax').text)

    labels_dict['filepath'].append(filename)
    labels_dict['xmin'].append(xmin)
    labels_dict['xmax'].append(xmax)
    labels_dict['ymin'].append(ymin)
    labels_dict['ymax'].append(ymax)

# %% [markdown]
# Read, process & extract the annotated Bounding Boxes information from the XML files

# %%
df = pd.DataFrame(labels_dict)
df.to_csv('labels.csv',index=False)
df.head()
# Out:
#                                             filepath  xmin  xmax  ymin  ymax
# 0  /content/drive/MyDrive/car-plate-detection/ann...   134   262   128   160
# 1  /content/drive/MyDrive/car-plate-detection/ann...   226   419   125   173
# 2  /content/drive/MyDrive/car-plate-detection/ann...   195   244   266   282
# 3  /content/drive/MyDrive/car-plate-detection/ann...   230   248   129   134
# 4  /content/drive/MyDrive/car-plate-detection/ann...   138   177    79    92

# %% [markdown]
# Sample output of the retrieved data

# %%
from PIL import Image
import requests
url = 'https://images.bfmtv.com/P-SjIS8mmRWOWD1ZrV46gt7j37w=/6x4:1254x706/800x0/images/-158334.jpg'
im = Image.open(requests.get(url, stream=True).raw)
im.save('/content/carTest.jpg')

# %% [markdown]
# save test picture to local folder

# %%
def getFilename(filename):
    filename_image = xet.parse(filename).getroot().find('filename').text
    filepath_image = os.path.join('/content/drive/MyDrive/car-plate-detection/images/',filename_image)
    return filepath_image

# %% [markdown]
# Properly format the filepath

# %%
image_path = list(df['filepath'].apply(getFilename))
file_path = image_path[87]
img = cv2.imread(file_path) #read the image
img = io.imread(file_path) #Read the image
fig = px.imshow(img)
fig.update_layout(width=600, height=500, margin=dict(l=10, r=10, b=10, t=10),xaxis_title='Cars333.png with bounding box')
fig.add_shape(type='rect',x0=df['xmin'][87], x1=df['xmax'][87], y0=df['ymin'][87], y1=df['ymax'][87], xref='x', yref='y',line_color='cyan')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="99f7e851-7c59-4857-8f73-bc49fd56c0be" class="plotly-graph-div" style="height:500px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("99f7e851-7c59-4857-8f73-bc49fd56c0be")) {                    Plotly.newPlot(                        "99f7e851-7c59-4857-8f73-bc49fd56c0be",                        [{"name":"0","source":"...\u002f5Wu5b9\u002fiB\u002f\u002fo3M+\u002f9+0JmtUdfvJX6+RHC5ycT5DPJJEyzujYSX7nB\u002f8jQ\u002flzbK494U\u002f\u002f5M9IpTLEbMHMdBalLTa2fWw3CbpNs9Oh5zdRfo+go0glJeNT07R9Sb0d0PV9ol6PqNchFU8wPjUB0gIkWgukZWPZFlJIHNdh\u002ftQCheEhqs0DUukhbCxePLpLvVHn3Otv8x8+\u002foLtlg+WgxQaS
GtFDYEjxp0eh2CbNJnJhFKR8nFgmUimEJiY4kyXgS13NJpUpYTgJhQbfXQIU+vbEWgd9jaGSKRHaYUAssItqtMmG3QSE\u002fgnTzKGHqbrsOEHDr4z8hXmwRH32LSk\u002fT2Nsml\u002fdJZwpIJ4UvMzheAmlJ0AItBFrroxn5K6RRBHjJEVKJEtqOobVC6K9phz4Z5WyutVJEQR3VO8DvHrCzvcLe7gbdriY3rDh14QSeE0PrI6DSSnM8e9Fv369y9ivUjyDEUdzfmE4f\u002fgGhv65nv5Z0f\u002fwcnxgfJ\u002fFrC+zTr0k3oEE7HN5r+vz9LQn7dBTfkKDP8yCgX4DAtC0IlFIm7Hjj9S8GyZTWgD60NP8upLVECkm7c8Dy82cUE2MMp0+yv3WH2\u002f5\u002foTaxzpXz\u002f4x4LM5AWfhhiG0ZWVUqwpKvWshaaxzXpdft0u11iScT9IIAoTSpWIxWq0svqvFyZxf3\u002fO\u002fR3fiEyfnznDxzgUbVY+rEFA+XPmF7\u002fSW7818wcfLv0el2eLm0wvjoCMXiEJcuXufLX\u002f4pxWyOyLcJw2GEsAn8ADtuIxEMF0rcvXOLytYmvoLi6DjZ0gSpVJETs6eo1jYYmiohUifY3lhm8fkip85fIpbIo5RG+zVq3SbJVJp2vUxtd5mou0e76bNbDUlnhpk6cQ47Ujz74iPyw1OcvPgmX3z5iGQyTq\u002fXI55MYFsaWegyMTXO0rMXVPdCNpYfEwQtnMx5Xq4GBPZDhofeoNFoM1RK ...

# %% [markdown]
# Example of a Car picture & its License Plate Bounding box

# %%
#Targeting all our values in array selecting all columns
labels = df.iloc[:,1:].values
data = []
output = []
for ind in range(len(image_path)):
    image = image_path[ind]
    img_arr = cv2.imread(image)
    h,w,d = img_arr.shape
    # Prepprocesing
    load_image = load_img(image,target_size=(224,224))
    load_image_arr = img_to_array(load_image)
    norm_load_image_arr = load_image_arr/255.0 # Normalization
    # Normalization to labels
    xmin,xmax,ymin,ymax = labels[ind]
    nxmin,nxmax = xmin/w,xmax/w
    nymin,nymax = ymin/h,ymax/h
    label_norm = (nxmin,nxmax,nymin,nymax) # Normalized output
    # Append
    data.append(norm_load_image_arr)
    output.append(label_norm)

# %% [markdown]
# Iterate through each picture to associate them with their bounding boxes coordinates

# %%
X = np.array(data,dtype=np.float32)
y = np.array(output,dtype=np.float32)

# %% [markdown]
# Convert data to array

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,train_size=0.8,random_state=0)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((346, 224, 224, 3), (87, 224, 224, 3), (346, 4), (87, 4))

# %% [markdown]
# Split the data into training and testing set using sklearn.

# %%
inception_resnet = InceptionResNetV2(weights="imagenet",include_top=False, input_tensor=Input(shape=(224,224,3)))
# ---------------------
headmodel = inception_resnet.output
headmodel = Flatten()(headmodel)
headmodel = Dense(500,activation="relu")(headmodel)
headmodel = Dense(250,activation="relu")(headmodel)
headmodel = Dense(4,activation='sigmoid')(headmodel)


# ---------- model
model = Model(inputs=inception_resnet.input,outputs=headmodel)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219055592/219055592 [==============================] - 1s 0us/step

# %% [markdown]
# construct the model

# %%
model.compile(loss='mse',optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4))
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 111, 111, 32)         864       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 111, 111, 32)         96        ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 111, 111, 32)         0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 32)         9216      ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 109, 109, 32)         96        ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 109, 109, 32)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_2 (Conv2D)           (None, 109, 109, 64)         18432     ['activation_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 109, 109, 64)         192       ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 109, 109, 64)         0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  max_pooling2d (MaxPooling2  (None, 54, 54, 64)           0         ['activation_2[0][0]']
#  D)
#
#  conv2d_3 (Conv2D)           (None, 54, 54, 80)           5120      ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (Bat  (None, 54, 54, 80)           240       ['conv2d_3[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 54, 54, 80)           0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv2d_4 (Conv2D)           (None, 52, 52, 192)          138240    ['activation_3[0][0]']
#
#  batch_normalization_4 (Bat  (None, 52, 52, 192)          576       ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 52, 52, 192)          0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  max_pooling2d_1 (MaxPoolin  (None, 25, 25, 192)          0         ['activation_4[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 25, 25, 64)           12288     ['max_pooling2d_1[0][0]']
#
#  batch_normalization_8 (Bat  (None, 25, 25, 64)           192       ['conv2d_8[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, 25, 25, 64)           0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_6 (Conv2D)           (None, 25, 25, 48)           9216      ['max_pooling2d_1[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 25, 25, 96)           55296     ['activation_8[0][0]']
#
#  batch_normalization_6 (Bat  (None, 25, 25, 48)           144       ['conv2d_6[0][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, 25, 25, 96)           288       ['conv2d_9[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 25, 25, 48)           0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  activation_9 (Activation)   (None, 25, 25, 96)           0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  average_pooling2d (Average  (None, 25, 25, 192)          0         ['max_pooling2d_1[0][0]']
#  Pooling2D)
#
#  conv2d_5 (Conv2D)           (None, 25, 25, 96)           18432     ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 25, 25, 64)           76800     ['activation_6[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 25, 25, 96)           82944     ['activation_9[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 25, 25, 64)           12288     ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (Bat  (None, 25, 25, 96)           288       ['conv2d_5[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 25, 25, 64)           192       ['conv2d_7[0][0]']
#  chNormalization)
#
#  batch_normalization_10 (Ba  (None, 25, 25, 96)           288       ['conv2d_10[0][0]']
#  tchNormalization)
#
#  batch_normalization_11 (Ba  (None, 25, 25, 64)           192       ['conv2d_11[0][0]']
#  tchNormalization)
#
#  activation_5 (Activation)   (None, 25, 25, 96)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  activation_7 (Activation)   (None, 25, 25, 64)           0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  activation_10 (Activation)  (None, 25, 25, 96)           0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  activation_11 (Activation)  (None, 25, 25, 64)           0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  mixed_5b (Concatenate)      (None, 25, 25, 320)          0         ['activation_5[0][0]',
#                                                                      'activation_7[0][0]',
#                                                                      'activation_10[0][0]',
#                                                                      'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 25, 25, 32)           10240     ['mixed_5b[0][0]']
#
#  batch_normalization_15 (Ba  (None, 25, 25, 32)           96        ['conv2d_15[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_13 (Conv2D)          (None, 25, 25, 32)           10240     ['mixed_5b[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 25, 25, 48)           13824     ['activation_15[0][0]']
#
#  batch_normalization_13 (Ba  (None, 25, 25, 32)           96        ['conv2d_13[0][0]']
#  tchNormalization)
#
#  batch_normalization_16 (Ba  (None, 25, 25, 48)           144       ['conv2d_16[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  activation_16 (Activation)  (None, 25, 25, 48)           0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv2d_12 (Conv2D)          (None, 25, 25, 32)           10240     ['mixed_5b[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 25, 25, 32)           9216      ['activation_13[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 25, 25, 64)           27648     ['activation_16[0][0]']
#
#  batch_normalization_12 (Ba  (None, 25, 25, 32)           96        ['conv2d_12[0][0]']
#  tchNormalization)
#
#  batch_normalization_14 (Ba  (None, 25, 25, 32)           96        ['conv2d_14[0][0]']
#  tchNormalization)
#
#  batch_normalization_17 (Ba  (None, 25, 25, 64)           192       ['conv2d_17[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  activation_14 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  activation_17 (Activation)  (None, 25, 25, 64)           0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  block35_1_mixed (Concatena  (None, 25, 25, 128)          0         ['activation_12[0][0]',
#  te)                                                                 'activation_14[0][0]',
#                                                                      'activation_17[0][0]']
#
#  block35_1_conv (Conv2D)     (None, 25, 25, 320)          41280     ['block35_1_mixed[0][0]']
#
#  custom_scale_layer (Custom  (None, 25, 25, 320)          0         ['mixed_5b[0][0]',
#  ScaleLayer)                                                         'block35_1_conv[0][0]']
#
#  block35_1_ac (Activation)   (None, 25, 25, 320)          0         ['custom_scale_layer[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_1_ac[0][0]']
#
#  batch_normalization_21 (Ba  (None, 25, 25, 32)           96        ['conv2d_21[0][0]']
#  tchNormalization)
#
#  activation_21 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  conv2d_19 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_1_ac[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 25, 25, 48)           13824     ['activation_21[0][0]']
#
#  batch_normalization_19 (Ba  (None, 25, 25, 32)           96        ['conv2d_19[0][0]']
#  tchNormalization)
#
#  batch_normalization_22 (Ba  (None, 25, 25, 48)           144       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  activation_22 (Activation)  (None, 25, 25, 48)           0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_18 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_1_ac[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 25, 25, 32)           9216      ['activation_19[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 25, 25, 64)           27648     ['activation_22[0][0]']
#
#  batch_normalization_18 (Ba  (None, 25, 25, 32)           96        ['conv2d_18[0][0]']
#  tchNormalization)
#
#  batch_normalization_20 (Ba  (None, 25, 25, 32)           96        ['conv2d_20[0][0]']
#  tchNormalization)
#
#  batch_normalization_23 (Ba  (None, 25, 25, 64)           192       ['conv2d_23[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  activation_20 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  activation_23 (Activation)  (None, 25, 25, 64)           0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  block35_2_mixed (Concatena  (None, 25, 25, 128)          0         ['activation_18[0][0]',
#  te)                                                                 'activation_20[0][0]',
#                                                                      'activation_23[0][0]']
#
#  block35_2_conv (Conv2D)     (None, 25, 25, 320)          41280     ['block35_2_mixed[0][0]']
#
#  custom_scale_layer_1 (Cust  (None, 25, 25, 320)          0         ['block35_1_ac[0][0]',
#  omScaleLayer)                                                       'block35_2_conv[0][0]']
#
#  block35_2_ac (Activation)   (None, 25, 25, 320)          0         ['custom_scale_layer_1[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_2_ac[0][0]']
#
#  batch_normalization_27 (Ba  (None, 25, 25, 32)           96        ['conv2d_27[0][0]']
#  tchNormalization)
#
#  activation_27 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  conv2d_25 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_2_ac[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 25, 25, 48)           13824     ['activation_27[0][0]']
#
#  batch_normalization_25 (Ba  (None, 25, 25, 32)           96        ['conv2d_25[0][0]']
#  tchNormalization)
#
#  batch_normalization_28 (Ba  (None, 25, 25, 48)           144       ['conv2d_28[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  activation_28 (Activation)  (None, 25, 25, 48)           0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  conv2d_24 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_2_ac[0][0]']
#
#  conv2d_26 (Conv2D)          (None, 25, 25, 32)           9216      ['activation_25[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 25, 25, 64)           27648     ['activation_28[0][0]']
#
#  batch_normalization_24 (Ba  (None, 25, 25, 32)           96        ['conv2d_24[0][0]']
#  tchNormalization)
#
#  batch_normalization_26 (Ba  (None, 25, 25, 32)           96        ['conv2d_26[0][0]']
#  tchNormalization)
#
#  batch_normalization_29 (Ba  (None, 25, 25, 64)           192       ['conv2d_29[0][0]']
#  tchNormalization)
#
#  activation_24 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  activation_26 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  activation_29 (Activation)  (None, 25, 25, 64)           0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  block35_3_mixed (Concatena  (None, 25, 25, 128)          0         ['activation_24[0][0]',
#  te)                                                                 'activation_26[0][0]',
#                                                                      'activation_29[0][0]']
#
#  block35_3_conv (Conv2D)     (None, 25, 25, 320)          41280     ['block35_3_mixed[0][0]']
#
#  custom_scale_layer_2 (Cust  (None, 25, 25, 320)          0         ['block35_2_ac[0][0]',
#  omScaleLayer)                                                       'block35_3_conv[0][0]']
#
#  block35_3_ac (Activation)   (None, 25, 25, 320)          0         ['custom_scale_layer_2[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_3_ac[0][0]']
#
#  batch_normalization_33 (Ba  (None, 25, 25, 32)           96        ['conv2d_33[0][0]']
#  tchNormalization)
#
#  activation_33 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  conv2d_31 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_3_ac[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 25, 25, 48)           13824     ['activation_33[0][0]']
#
#  batch_normalization_31 (Ba  (None, 25, 25, 32)           96        ['conv2d_31[0][0]']
#  tchNormalization)
#
#  batch_normalization_34 (Ba  (None, 25, 25, 48)           144       ['conv2d_34[0][0]']
#  tchNormalization)
#
#  activation_31 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  activation_34 (Activation)  (None, 25, 25, 48)           0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  conv2d_30 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_3_ac[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 25, 25, 32)           9216      ['activation_31[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 25, 25, 64)           27648     ['activation_34[0][0]']
#
#  batch_normalization_30 (Ba  (None, 25, 25, 32)           96        ['conv2d_30[0][0]']
#  tchNormalization)
#
#  batch_normalization_32 (Ba  (None, 25, 25, 32)           96        ['conv2d_32[0][0]']
#  tchNormalization)
#
#  batch_normalization_35 (Ba  (None, 25, 25, 64)           192       ['conv2d_35[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  activation_32 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  activation_35 (Activation)  (None, 25, 25, 64)           0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  block35_4_mixed (Concatena  (None, 25, 25, 128)          0         ['activation_30[0][0]',
#  te)                                                                 'activation_32[0][0]',
#                                                                      'activation_35[0][0]']
#
#  block35_4_conv (Conv2D)     (None, 25, 25, 320)          41280     ['block35_4_mixed[0][0]']
#
#  custom_scale_layer_3 (Cust  (None, 25, 25, 320)          0         ['block35_3_ac[0][0]',
#  omScaleLayer)                                                       'block35_4_conv[0][0]']
#
#  block35_4_ac (Activation)   (None, 25, 25, 320)          0         ['custom_scale_layer_3[0][0]']
#
#  conv2d_39 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_4_ac[0][0]']
#
#  batch_normalization_39 (Ba  (None, 25, 25, 32)           96        ['conv2d_39[0][0]']
#  tchNormalization)
#
#  activation_39 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  conv2d_37 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_4_ac[0][0]']
#
#  conv2d_40 (Conv2D)          (None, 25, 25, 48)           13824     ['activation_39[0][0]']
#
#  batch_normalization_37 (Ba  (None, 25, 25, 32)           96        ['conv2d_37[0][0]']
#  tchNormalization)
#
#  batch_normalization_40 (Ba  (None, 25, 25, 48)           144       ['conv2d_40[0][0]']
#  tchNormalization)
#
#  activation_37 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  activation_40 (Activation)  (None, 25, 25, 48)           0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  conv2d_36 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_4_ac[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 25, 25, 32)           9216      ['activation_37[0][0]']
#
#  conv2d_41 (Conv2D)          (None, 25, 25, 64)           27648     ['activation_40[0][0]']
#
#  batch_normalization_36 (Ba  (None, 25, 25, 32)           96        ['conv2d_36[0][0]']
#  tchNormalization)
#
#  batch_normalization_38 (Ba  (None, 25, 25, 32)           96        ['conv2d_38[0][0]']
#  tchNormalization)
#
#  batch_normalization_41 (Ba  (None, 25, 25, 64)           192       ['conv2d_41[0][0]']
#  tchNormalization)
#
#  activation_36 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  activation_38 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  activation_41 (Activation)  (None, 25, 25, 64)           0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  block35_5_mixed (Concatena  (None, 25, 25, 128)          0         ['activation_36[0][0]',
#  te)                                                                 'activation_38[0][0]',
#                                                                      'activation_41[0][0]']
#
#  block35_5_conv (Conv2D)     (None, 25, 25, 320)          41280     ['block35_5_mixed[0][0]']
#
#  custom_scale_layer_4 (Cust  (None, 25, 25, 320)          0         ['block35_4_ac[0][0]',
#  omScaleLayer)                                                       'block35_5_conv[0][0]']
#
#  block35_5_ac (Activation)   (None, 25, 25, 320)          0         ['custom_scale_layer_4[0][0]']
#
#  conv2d_45 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_5_ac[0][0]']
#
#  batch_normalization_45 (Ba  (None, 25, 25, 32)           96        ['conv2d_45[0][0]']
#  tchNormalization)
#
#  activation_45 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  conv2d_43 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_5_ac[0][0]']
#
#  conv2d_46 (Conv2D)          (None, 25, 25, 48)           13824     ['activation_45[0][0]']
#
#  batch_normalization_43 (Ba  (None, 25, 25, 32)           96        ['conv2d_43[0][0]']
#  tchNormalization)
#
#  batch_normalization_46 (Ba  (None, 25, 25, 48)           144       ['conv2d_46[0][0]']
#  tchNormalization)
#
#  activation_43 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  activation_46 (Activation)  (None, 25, 25, 48)           0         ['batch_normalization_46[0][0]
#                                                                     ']
#
#  conv2d_42 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_5_ac[0][0]']
#
#  conv2d_44 (Conv2D)          (None, 25, 25, 32)           9216      ['activation_43[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 25, 25, 64)           27648     ['activation_46[0][0]']
#
#  batch_normalization_42 (Ba  (None, 25, 25, 32)           96        ['conv2d_42[0][0]']
#  tchNormalization)
#
#  batch_normalization_44 (Ba  (None, 25, 25, 32)           96        ['conv2d_44[0][0]']
#  tchNormalization)
#
#  batch_normalization_47 (Ba  (None, 25, 25, 64)           192       ['conv2d_47[0][0]']
#  tchNormalization)
#
#  activation_42 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  activation_44 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  activation_47 (Activation)  (None, 25, 25, 64)           0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  block35_6_mixed (Concatena  (None, 25, 25, 128)          0         ['activation_42[0][0]',
#  te)                                                                 'activation_44[0][0]',
#                                                                      'activation_47[0][0]']
#
#  block35_6_conv (Conv2D)     (None, 25, 25, 320)          41280     ['block35_6_mixed[0][0]']
#
#  custom_scale_layer_5 (Cust  (None, 25, 25, 320)          0         ['block35_5_ac[0][0]',
#  omScaleLayer)                                                       'block35_6_conv[0][0]']
#
#  block35_6_ac (Activation)   (None, 25, 25, 320)          0         ['custom_scale_layer_5[0][0]']
#
#  conv2d_51 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_6_ac[0][0]']
#
#  batch_normalization_51 (Ba  (None, 25, 25, 32)           96        ['conv2d_51[0][0]']
#  tchNormalization)
#
#  activation_51 (Activation)  (None, 25, 25, 32)           0         ['batch_normalization_51[0][0]
#                                                                     ']
#
#  conv2d_49 (Conv2D)          (None, 25, 25, 32)           10240     ['block35_6_ac[0][0]']
#
#  conv2d_52 (Conv2D)          (None, 25, 25, 48)           13824     ['activation_51[0][0]']
#
#  batch_normalization_49 (Ba  (None, 25, 25, 32)           96        ['conv2d_49[0][0]']
#  tchNormalization)
#
#  batch_normalization_52 (Ba  (None, 25, 25, 48)           144       ['conv2d_52[0][0]']
# ...
#
#  activation_190 (Activation  (None, 5, 5, 256)            0         ['batch_normalization_190[0][0
#  )                                                                  ]']
#
#  block8_7_mixed (Concatenat  (None, 5, 5, 448)            0         ['activation_187[0][0]',
#  e)                                                                  'activation_190[0][0]']
#
#  block8_7_conv (Conv2D)      (None, 5, 5, 2080)           933920    ['block8_7_mixed[0][0]']
#
#  custom_scale_layer_36 (Cus  (None, 5, 5, 2080)           0         ['block8_6_ac[0][0]',
#  tomScaleLayer)                                                      'block8_7_conv[0][0]']
#
#  block8_7_ac (Activation)    (None, 5, 5, 2080)           0         ['custom_scale_layer_36[0][0]'
#                                                                     ]
#
#  conv2d_192 (Conv2D)         (None, 5, 5, 192)            399360    ['block8_7_ac[0][0]']
#
#  batch_normalization_192 (B  (None, 5, 5, 192)            576       ['conv2d_192[0][0]']
#  atchNormalization)
#
#  activation_192 (Activation  (None, 5, 5, 192)            0         ['batch_normalization_192[0][0
#  )                                                                  ]']
#
#  conv2d_193 (Conv2D)         (None, 5, 5, 224)            129024    ['activation_192[0][0]']
#
#  batch_normalization_193 (B  (None, 5, 5, 224)            672       ['conv2d_193[0][0]']
#  atchNormalization)
#
#  activation_193 (Activation  (None, 5, 5, 224)            0         ['batch_normalization_193[0][0
#  )                                                                  ]']
#
#  conv2d_191 (Conv2D)         (None, 5, 5, 192)            399360    ['block8_7_ac[0][0]']
#
#  conv2d_194 (Conv2D)         (None, 5, 5, 256)            172032    ['activation_193[0][0]']
#
#  batch_normalization_191 (B  (None, 5, 5, 192)            576       ['conv2d_191[0][0]']
#  atchNormalization)
#
#  batch_normalization_194 (B  (None, 5, 5, 256)            768       ['conv2d_194[0][0]']
#  atchNormalization)
#
#  activation_191 (Activation  (None, 5, 5, 192)            0         ['batch_normalization_191[0][0
#  )                                                                  ]']
#
#  activation_194 (Activation  (None, 5, 5, 256)            0         ['batch_normalization_194[0][0
#  )                                                                  ]']
#
#  block8_8_mixed (Concatenat  (None, 5, 5, 448)            0         ['activation_191[0][0]',
#  e)                                                                  'activation_194[0][0]']
#
#  block8_8_conv (Conv2D)      (None, 5, 5, 2080)           933920    ['block8_8_mixed[0][0]']
#
#  custom_scale_layer_37 (Cus  (None, 5, 5, 2080)           0         ['block8_7_ac[0][0]',
#  tomScaleLayer)                                                      'block8_8_conv[0][0]']
#
#  block8_8_ac (Activation)    (None, 5, 5, 2080)           0         ['custom_scale_layer_37[0][0]'
#                                                                     ]
#
#  conv2d_196 (Conv2D)         (None, 5, 5, 192)            399360    ['block8_8_ac[0][0]']
#
#  batch_normalization_196 (B  (None, 5, 5, 192)            576       ['conv2d_196[0][0]']
#  atchNormalization)
#
#  activation_196 (Activation  (None, 5, 5, 192)            0         ['batch_normalization_196[0][0
#  )                                                                  ]']
#
#  conv2d_197 (Conv2D)         (None, 5, 5, 224)            129024    ['activation_196[0][0]']
#
#  batch_normalization_197 (B  (None, 5, 5, 224)            672       ['conv2d_197[0][0]']
#  atchNormalization)
#
#  activation_197 (Activation  (None, 5, 5, 224)            0         ['batch_normalization_197[0][0
#  )                                                                  ]']
#
#  conv2d_195 (Conv2D)         (None, 5, 5, 192)            399360    ['block8_8_ac[0][0]']
#
#  conv2d_198 (Conv2D)         (None, 5, 5, 256)            172032    ['activation_197[0][0]']
#
#  batch_normalization_195 (B  (None, 5, 5, 192)            576       ['conv2d_195[0][0]']
#  atchNormalization)
#
#  batch_normalization_198 (B  (None, 5, 5, 256)            768       ['conv2d_198[0][0]']
#  atchNormalization)
#
#  activation_195 (Activation  (None, 5, 5, 192)            0         ['batch_normalization_195[0][0
#  )                                                                  ]']
#
#  activation_198 (Activation  (None, 5, 5, 256)            0         ['batch_normalization_198[0][0
#  )                                                                  ]']
#
#  block8_9_mixed (Concatenat  (None, 5, 5, 448)            0         ['activation_195[0][0]',
#  e)                                                                  'activation_198[0][0]']
#
#  block8_9_conv (Conv2D)      (None, 5, 5, 2080)           933920    ['block8_9_mixed[0][0]']
#
#  custom_scale_layer_38 (Cus  (None, 5, 5, 2080)           0         ['block8_8_ac[0][0]',
#  tomScaleLayer)                                                      'block8_9_conv[0][0]']
#
#  block8_9_ac (Activation)    (None, 5, 5, 2080)           0         ['custom_scale_layer_38[0][0]'
#                                                                     ]
#
#  conv2d_200 (Conv2D)         (None, 5, 5, 192)            399360    ['block8_9_ac[0][0]']
#
#  batch_normalization_200 (B  (None, 5, 5, 192)            576       ['conv2d_200[0][0]']
#  atchNormalization)
#
#  activation_200 (Activation  (None, 5, 5, 192)            0         ['batch_normalization_200[0][0
#  )                                                                  ]']
#
#  conv2d_201 (Conv2D)         (None, 5, 5, 224)            129024    ['activation_200[0][0]']
#
#  batch_normalization_201 (B  (None, 5, 5, 224)            672       ['conv2d_201[0][0]']
#  atchNormalization)
#
#  activation_201 (Activation  (None, 5, 5, 224)            0         ['batch_normalization_201[0][0
#  )                                                                  ]']
#
#  conv2d_199 (Conv2D)         (None, 5, 5, 192)            399360    ['block8_9_ac[0][0]']
#
#  conv2d_202 (Conv2D)         (None, 5, 5, 256)            172032    ['activation_201[0][0]']
#
#  batch_normalization_199 (B  (None, 5, 5, 192)            576       ['conv2d_199[0][0]']
#  atchNormalization)
#
#  batch_normalization_202 (B  (None, 5, 5, 256)            768       ['conv2d_202[0][0]']
#  atchNormalization)
#
#  activation_199 (Activation  (None, 5, 5, 192)            0         ['batch_normalization_199[0][0
#  )                                                                  ]']
#
#  activation_202 (Activation  (None, 5, 5, 256)            0         ['batch_normalization_202[0][0
#  )                                                                  ]']
#
#  block8_10_mixed (Concatena  (None, 5, 5, 448)            0         ['activation_199[0][0]',
#  te)                                                                 'activation_202[0][0]']
#
#  block8_10_conv (Conv2D)     (None, 5, 5, 2080)           933920    ['block8_10_mixed[0][0]']
#
#  custom_scale_layer_39 (Cus  (None, 5, 5, 2080)           0         ['block8_9_ac[0][0]',
#  tomScaleLayer)                                                      'block8_10_conv[0][0]']
#
#  conv_7b (Conv2D)            (None, 5, 5, 1536)           3194880   ['custom_scale_layer_39[0][0]'
#                                                                     ]
#
#  conv_7b_bn (BatchNormaliza  (None, 5, 5, 1536)           4608      ['conv_7b[0][0]']
#  tion)
#
#  conv_7b_ac (Activation)     (None, 5, 5, 1536)           0         ['conv_7b_bn[0][0]']
#
#  flatten (Flatten)           (None, 38400)                0         ['conv_7b_ac[0][0]']
#
#  dense (Dense)               (None, 500)                  1920050   ['flatten[0][0]']
#                                                           0
#
#  dense_1 (Dense)             (None, 250)                  125250    ['dense[0][0]']
#
#  dense_2 (Dense)             (None, 4)                
80
# 35/35 [==============================] - 8s 242ms/step - loss: 0.0010 - val_loss: 0.0196
# Epoch 48/80
# 35/35 [==============================] - 8s 240ms/step - loss: 0.0013 - val_loss: 0.0181
# Epoch 49/80
# 35/35 [==============================] - 8s 241ms/step - loss: 0.0011 - val_loss: 0.0158
# Epoch 50/80
# 35/35 [==============================] - 8s 241ms/step - loss: 0.0012 - val_loss: 0.0184
# Epoch 51/80
# 35/35 [==============================] - 8s 240ms/step - loss: 0.0012 - val_loss: 0.0178
# Epoch 52/80
# 35/35 [==============================] - 8s 243ms/step - loss: 0.0012 - val_loss: 0.0191
# Epoch 53/80
# 35/35 [==============================] - 8s 238ms/step - loss: 0.0012 - val_loss: 0.0189
# Epoch 54/80
# 35/35 [==============================] - 8s 242ms/step - loss: 0.0011 - val_loss: 0.0187
# Epoch 55/80
# 35/35 [==============================] - 8s 239ms/step - loss: 0.0011 - val_loss: 0.0197
# Epoch 56/80
# 35/35 [==============================] - 8s 241ms/step - loss: 0.0012 - val_loss: 0.0179
# Epoch 57/80
# 35/35 [==============================] - 8s 241ms/step - loss: 0.0012 - val_loss: 0.0179
# Epoch 58/80
# 35/35 [==============================] - 8s 240ms/step - loss: 0.0013 - val_loss: 0.0182
# Epoch 59/80
# 35/35 [==============================] - 8s 241ms/step - loss: 0.0012 - val_loss: 0.0180
# Epoch 60/80
# 35/35 [==============================] - 8s 239ms/step - loss: 0.0011 - val_loss: 0.0139
# Epoch 61/80
# 35/35 [==============================] - 8s 243ms/step - loss: 0.0010 - val_loss: 0.0154
# Epoch 62/80
# 35/35 [==============================] - 8s 242ms/step - loss: 0.0011 - val_loss: 0.0148
# Epoch 63/80
# 35/35 [==============================] - 8s 239ms/step - loss: 0.0012 - val_loss: 0.0143
# Epoch 64/80
# 35/35 [==============================] - 9s 244ms/step - loss: 0.0012 - val_loss: 0.0177
# Epoch 65/80
# 35/35 [==============================] - 8s 238ms/step - loss: 0.0012 - val_loss: 0.0151
# Epoch 66/80
# 35/35 [==============================] - 8s 243ms/step - loss: 0.0011 - val_loss: 0.0116
# Epoch 67/80
# 35/35 [==============================] - 8s 241ms/step - loss: 0.0012 - val_loss: 0.0127
# Epoch 68/80
# 35/35 [==============================] - 8s 241ms/step - loss: 0.0011 - val_loss: 0.0137
# Epoch 69/80
# 35/35 [==============================] - 8s 242ms/step - loss: 0.0012 - val_loss: 0.0117
# Epoch 70/80
# 35/35 [==============================] - 8s 237ms/step - loss: 0.0011 - val_loss: 0.0111
# Epoch 71/80
# 35/35 [==============================] - 8s 241ms/step - loss: 0.0011 - val_loss: 0.0106
# Epoch 72/80
# 35/35 [==============================] - 8s 239ms/step - loss: 0.0011 - val_loss: 0.0106
# Epoch 73/80
# 35/35 [==============================] - 8s 242ms/step - loss: 0.0011 - val_loss: 0.0105
# Epoch 74/80
# 35/35 [==============================] - 8s 241ms/step - loss: 0.0011 - val_loss: 0.0108
# Epoch 75/80
# 35/35 [==============================] - 8s 240ms/step - loss: 0.0010 - val_loss: 0.0105
# Epoch 76/80
# 35/35 [==============================] - 8s 241ms/step - loss: 0.0010 - val_loss: 0.0139
# Epoch 77/80
# 35/35 [==============================] - 8s 238ms/step - loss: 0.0011 - val_loss: 0.0118
# Epoch 78/80
# 35/35 [==============================] - 8s 242ms/step - loss: 0.0011 - val_loss: 0.0125
# Epoch 79/80
# 35/35 [==============================] - 8s 242ms/step - loss: 0.0011 - val_loss: 0.0132
# Epoch 80/80
# 35/35 [==============================] - 8s 238ms/step - loss: 0.0010 - val_loss: 0.0131

# %% [markdown]
# Train model

# %%
model.save('/content/drive/MyDrive/car-plate-detection/object_detection.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning:
#
# You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.

# %% [markdown]
# Save model weights locally to ensure they're properly constructed. The ".keras" extension is more modern but caused issues during testing, hence the reversion to the ".h5" extension.

# %%
# Load model
model = tf.keras.models.load_model('/content/drive/MyDrive/car-plate-detection/object_detection.h5')
print('Model loaded Sucessfully')
# Out:
# Model loaded Sucessfully

# %%
path = '/content/drive/MyDrive/car-plate-detection/images/Cars0.png'
image = load_img(path) # PIL object
image = np.array(image,dtype=np.uint8) # 8 bit array (0,255)
image1 = load_img(path,target_size=(224,224))
image_arr_224 = img_to_array(image1)/255.0  # Convert into array and get the normalized output

# Size of the orginal image
h,w,d = image.shape
print('Height of the image =',h)
print('Width of the image =',w)
# Out:
# Height of the image = 268
# Width of the image = 500

# %% [markdown]
# Show a test picture

# %%
fig = px.imshow(image)
fig.update_layout(width=700, height=500,  margin=dict(l=10, r=10, b=10, t=10), xaxis_title='TEST Image')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="76098151-65dd-45da-860b-66a041b648af" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("76098151-65dd-45da-860b-66a041b648af")) {                    Plotly.newPlot(                        "76098151-65dd-45da-860b-66a041b648af",                        [{"name":"0","source":"...\u002fBLkhA4ALCCtIfCdAPARIWJCDsDy4gQVguSA1ndg5yeHR1T083u7uOrqrMyjryqrwiIzLu+M53+GH6Ye+9ePlFZnYtdw0fPvgzNzc3dzc3Nz+eP1z+q3\u002fn5a\u002f8wqajzOHU1NRCEi1GNCttYEZTAWrnbn98bbi310qC6bl2brIw7gLAqD9ot9vdbjeKop2t3Y2Njeuf3jh8+OjrX\u002f7Kxx9f\u002f+M\u002f+ROlwq997Wu\u002f\u002fmt\\u002f\u002fWPAwWa6DZayRiEjkqsB+oyPiweJXsWXD8WOzyWoOjCzxIGt8k7LmXyfhgBCCw02aOu1B4FQ\u002fF2oy7x\u002fTllpO\u002fzg0o5xz3nsi8mSdK6trPB4657wzTE9ErPZRmPgqC+6heZ7XPVpKqcqOI5k\u002f9x1jTJZleZ5zd+BKcM455+p64DopJWmUgsAREWchpYyiKAi0tbbX6w2HwzDUACDQCSF0oLTWWmspFEg1HOSb27293dHm7jBLTRR3lAqGNOOcI3KImGajbrf70x\u002f\u002fcG9v7+tvviGllIIQkcjcv39\u002fcWEhSZLURVLqzPo4iKWklZuf3L\u002f+XpJvn10Kf+HiqcANFVlE6UlnTrzz7vvvuTlf5Euzs5KIlLBEPun8wi99a3p+0RQ+AIXeCVHkJoXIfvf7b618+OHhI8fe\u002fKVfTo3b2e2BVK7Is3QUKZWPhlevfthtTxXkBGodtZwl7b3WepiPnPeFzQtnAUSWZd1W11sHANk4RSmmp6ejJFRKmYK4\u002fpVSKlCYpYPCayf0aDBMtx5tjLbbPj06l6xko\u002f7m9nSSJO3288+fTIvBsZmjWiVRFCkhuamCIOi02nMzs9PdqY8\u002f\u002fvTP\u002f\u002fzPX3rp5X\u002fwD\u002f7Bv\u002f23\u002f\u002f7P\u002fuzPrl279uY3v\u002fLaa6+dO3fOObfX6xGRCIS1NkmSLMuEEO044dYVQgRBYJ0TQpSKSFC3\u002fT4SAAFYV6y1WZYhYhAESpUtLbQSQrBysAJRo8MYY1jbAKDWvCAItJTWWmMs0xRFIYSIokgpyXmxKhPReDxGxHZLICIrNwBYa4lIKVVbec6Os65zbEZVj4\u002fRIyJAqfoNmicbgiY8jX85JNRPT2L17LzKOj+AL5EHYumZVuyJfJ4GNavH62c\\u002fY00aaEQirVAQpdmQiKJAx2FIzklFzuWRCoEKCSJLhxpBSZzpTqsgdOnIOS+FBiWNhwIAlFAyFEp65wFQhmEQt8ZZvnN\u002fBZ0MReBNUZixdenUoa6UrYL04uFTQrcDDYvJbBhFSgpTZDPt9vVPrqKMCg8EGlRgvXDeK6ly54+fOHPx0qWCHHux\u002fb3eD37w\u002fUCpUKuvv\u002fkrm1tb\u002ff4wN4X3QODyIk2SpNfrqU4kweaOgFAUJusqsTDdPj41e2y+c\u002fVn70RJsjsYtpYWT5w5G4UuSQKbURiG3W53c3Nzd3cXAKJQQyc5po\u002fMzs7euvX5tY+vJK32t\u002f\u002fKt771rW\u002f+4R\u002f+4f\u002f3\u002f\u002f3\u002f+eFf\u002fODrX\u002f\u002f6m2++eWh5qSgKa10rbNncKlCBChAwy1KBGEWRlODICCEkIAFR5bUxAJRmHQCcc6w3iMhmPQgC1kuPkz2tBkQUlftPRESOyAtAROTOluc5jxZRFAkh8jzPskJKCQBhGMZxzC4JJ1dKhUEcx3EQBADgvVdKsRIzUMPMHQxUwKKWJa0eS6j87maXnkhewgG2FbIqbPlY\...\u002flDqKQ7W92xdCSIlxEk7NdHZ7O4iEJAAgbseZyQpXkCA1FelEY+jBKCEctQMd2qHPhz\u002f98fv5aCgxGfaGb\u002f7CNzzBKE2Hox0\u002fAiJaXl4e9fpkrA4CHUaRDna81TPdixcvHDt27MrVa\u002f\u002fm3\u002fyrl166\u002fPd\u002f\u002f29\u002fcOWDd95555\u002f9s3\u002f29ttv\u002f9X\u002f5DfeeOONTqczGo2EEEII7z0ixlHkvecRXscRIoIvNZL1SUrpnAMAqhx5HtWJKI5jdp9Zdbz37nH7WCsN65BW2jnH+QohAcBVE0lEZH+fXQ9rbVEUQRBBNcllmYlIKTUYDKSUWuXW2k6nwzrKmoeP24j68SBgNagcpKkw1Ag\u002fC+pi1sDyYGOoY9n48efynCjFM6AmaMrAyGbl11FfBPbpn5KwWbecS\u002f3\u002fNMmrCplETshfc56oqGaOTcwENEWqAxP5EhEb6yYBP7I+fEGoheQwP3JGNR\u002fWWI4iotFoxJRaa6VLD917PzMzY601eWGMsa6o+5dAxQHmxkygsrw1so4iIkT0VT\u002flACKKahpRi8edmnsiIysoCbi7cbgGBElAIAjRCRJEBMoTkbHWWg8oQq2ty\u002fuDTKvQez8zNT338vMnj8\u002fev3vv7v17WxubiXZKqYf3b1hrhRBEKAABwObjfr9faERPR4+cDLRGKSPtdRJ6rz3qfm7JKSEUyjB1rg8SOzPoJErlPGgVCCWTVmdqZg6FGA3H7VgJIb21SqACOeyPtje2o\u002fZskEyJIEwwNNZ778epwUgpLcbjwjq0FlCIIAgL65wjI8GrIJlayJzMnEbnrbeP1rdVEBqXhrG+devGzs5eO ...

# %%
test_arr = image_arr_224.reshape(1,224,224,3)
coords = model.predict(test_arr)
denorm = np.array([w,w,h,h])
coords = coords * denorm
# Out:
# 1/1 [==============================] - 5s 5s/step

# %% [markdown]
# Begin Prediction

# %%
coords = coords.astype(np.int32)
xmin, xmax,ymin,ymax = coords[0]
pt1 =(xmin,ymin)
pt2 =(xmax,ymax)
print(pt1, pt2)
# Out:
# (235, 127) (431, 169)

# %%
cv2.rectangle(image,pt1,pt2,(0,255,0),3)
fig = px.imshow(image)
fig.update_layout(width=700, height=500, margin=dict(l=10, r=10, b=10, t=10),  xaxis_title="test picture")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e621b66c-6076-4073-9c68-35691a8cb1d6" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e621b66c-6076-4073-9c68-35691a8cb1d6")) {                    Plotly.newPlot(                        "e621b66c-6076-4073-9c68-35691a8cb1d6",                        [{"name":"0","source":"...\u002fBLkhA4ALCCtIfCdAPARIWJCDsDy4gQVguSA1ndg5yeHR1T083u7uOrqrMyjryqrwiIzLu+M53+GH6Ye+9ePlFZnYtdw0fPvgzNzc3dzc3Nz+eP1z+q3\u002fn5a\u002f8wqajzOHU1NRCEi1GNCttYEZTAWrnbn98bbi310qC6bl2brIw7gLAqD9ot9vdbjeKop2t3Y2Njeuf3jh8+OjrX\u002f7Kxx9f\u002f+M\u002f+ROlwq997Wu\u002f\u002fmt\\u002f\u002fWPAwWa6DZayRiEjkqsB+oyPiweJXsWXD8WOzyWoOjCzxIGt8k7LmXyfhgBCCw02aOu1B4FQ\u002fF2oy7x\u002fTllpO\u002fzg0o5xz3nsi8mSdK6trPB4657wzTE9ErPZRmPgqC+6heZ7XPVpKqcqOI5k\u002f9x1jTJZleZ5zd+BKcM455+p64DopJWmUgsAREWchpYyiKAi0tbbX6w2HwzDUACDQCSF0oLTWWmspFEg1HOSb27293dHm7jBLTRR3lAqGNOOcI3KImGajbrf70x\u002f\u002fcG9v7+tvviGllIIQkcjcv39\u002fcWEhSZLURVLqzPo4iKWklZuf3L\u002f+XpJvn10Kf+HiqcANFVlE6UlnTrzz7vvvuTlf5Euzs5KIlLBEPun8wi99a3p+0RQ+AIXeCVHkJoXIfvf7b618+OHhI8fe\u002fKVfTo3b2e2BVK7Is3QUKZWPhlevfthtTxXkBGodtZwl7b3WepiPnPeFzQtnAUSWZd1W11sHANk4RSmmp6ejJFRKmYK4\u002fpVSKlCYpYPCayf0aDBMtx5tjLbbPj06l6xko\u002f7m9nSSJO3288+fTIvBsZmjWiVRFCkhuamCIOi02nMzs9PdqY8\u002f\u002fvTP\u002f\u002fzPX3rp5X\u002fwD\u002f7Bv\u002f23\u002f\u002f7P\u002fuzPrl279uY3v\u002fLaa6+dO3fOObfX6xGRCIS1NkmSLMuEEO044dYVQgRBYJ0TQpSKSFC3\u002fT4SAAFYV6y1WZYhYhAESpUtLbQSQrBysAJRo8MYY1jbAKDWvCAItJTWWmMs0xRFIYSIokgpyXmxKhPReDxGxHZLICIrNwBYa4lIKVVbec6Os65zbEZVj4\u002fRIyJAqfoNmicbgiY8jX85JNRPT2L17LzKOj+AL5EHYumZVuyJfJ4GNavH62c\\u002fY00aaEQirVAQpdmQiKJAx2FIzklFzuWRCoEKCSJLhxpBSZzpTqsgdOnIOS+FBiW
= np.array(image,dtype=np.uint8) # 8 bit array (0,255)
    image1 = load_img(path,target_size=(224,224))

    # Data preprocessing
    image_arr_224 = img_to_array(image1)/255.0 # Convert to array & normalized
    h,w,d = image.shape
    test_arr = image_arr_224.reshape(1,224,224,3)

    # Make predictions
    coords = model.predict(test_arr)

    # Denormalize the values
    denorm = np.array([w,w,h,h])
    coords = coords * denorm
    coords = coords.astype(np.int32)

    # Draw bounding on top the image
    xmin, xmax,ymin,ymax = coords[0]
    pt1 =(xmin,ymin)
    pt2 =(xmax,ymax)
    print(pt1, pt2)
    cv2.rectangle(image,pt1,pt2,(0,255,0),3)
    return image, coords

image, cods = object_detection(path)

fig = px.imshow(image)
fig.update_layout(width=700, height=500, margin=dict(l=10, r=10, b=10, t=10),xaxis_title='Bounding Box Prediction')
# Out:
# 1/1 [==============================] - 0s 39ms/step
# (316, 249) (498, 306)
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="88e22227-b365-4d45-90e8-b50782872523" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("88e22227-b365-4d45-90e8-b50782872523")) {                    Plotly.newPlot(                        "88e22227-b365-4d45-90e8-b50782872523",                        [{"name":"0","source":"...\u002felSd37szIyMjMyMjYufHf\u002fcXbcBQQ8WDUE0FEB6MAABiQAeRg9EeHGeXOxAem14pX1Rf5GIkHAGRBRCLSEkWEmUXkaDqRiQCAD8ZP0bmffiIwAOPMp+KBmfVnVToionBwzhKyGEZIk7qNo263v7m5ORr0v\u002fEXf\u002f7Nv\u002fxGd2crTSIUXwyGvnS+ACKbJEnh3U57GyL7ua9++Vd\u002f49dPnD4VCASAQRgBAFiEEfr5MEqSmExw3gLGaIo873e6n33506+++uo3v\u002fGNu3fvWmubzSYA5Hm+vLycpqm11jkXQlBSmVm5pOwKIVQxyje9pTzRgLU2hBBCEJFxXUUAIAJyzgFAFEVC6L0HQmutD4GZvTAzBxkznADFB5risGal\u002fKwCSg8AoAAGjzzhAAhMGi9KYhEBYBERCCIiwigQQYT6YwKlP01TpWEaDFAUhYmstRYRtVwiIiJrrfdeq2aMiaJI0\u002fRHfX1WsxUREgAAQwST6pjxvwgAjGMeVtfq8SpcISBgGgUEEmBmDCwiFggRxXnv\u002fXyjyczgAiLmw1HSqEGUeBTlnpaodTfGwJS4VgHioLUzxmgafQQRNVJEyrIcjUZ5npfOIUZ8SB4AwFqrz05DEIyJZP\u002foh1OtTIAAUPEHARIbGSQ0hIhCCAAsAgDa4nspEVVsirLUrCYZjMsyxiAiEVX1CiE4DtZa2aNlD\u002fpUFah+wqSyGqnSqB2nSjANlRZEFboxG621aZoy8+bmZrfbnZ+fn5+fz\u002fO81+s1Gg1E7Pf7n\u002f70pxcXF1977bU8zxcXF40xRVGISJqmSZIoAWSstTHZOIoSay2CUZn03me1RMss3XAw6G9urt+9d3vj4QNb5uJKY0ySJABgrV1eXl45fiwfeZukX\u002fmlX\u002fqt3\u002f7dpdXjuQ\u002fBY1GOiEtDoByr+otWXCs43eja3QCPGD+PhhAzABzNuo8VE4L3R2odj5KHI9PD7PgK+\u002fnzkWFWhrPiP27MKHe\u002fPMh0Q2t4H68FgBGO7I9V\u002fgf4ecQo8wkAQHvpwdgfA4gIfAiFtaJ\u002fOr0Oo\u002fvSHQIRAQGKIJAge+9Ho1G\u002f371+7f179+51dnfy0cgIE7IqK9ZGIlh654VrrfmV0ycuXbp0+vTpUgIzBNWuBEREpTOO49FwCHHSqNXBh1A4IqrX62tra7du3Xr06FEIodFoGGO898YYnRh0uERErVSldlRDaoWqIlPVP7ri40hDIQ9
laIos7OzCKE0TXO5nG3b5XL58OHDjz322OOPP37+wjmUpkvTo4pSKpUKhcLtt9\u002f+vve9b3CgVwjhuq6iKNADpbSvry8Mw8ce23v\u002f\u002ffc\u002f+OCD1XKZyDJnDAkha9rmzZvf+c53XnfddWvXrl2xYoXjeEudI\u002fSKxcUYM8YWFhbuv\u002f\u002f+2akpLEmWZV199dU7d16OEBJCCCEIpkvXaZo2Go277777hf3Py7KsKJKqyoVCF0rRuXMXvva1r5XLZbCOt9566+c\u002f\u002f3khhBAYIYEQ5jwVAoPU\u002fvf\u002f\u002ft933323hBBGgiAsCcxTxgxdC8NQlmWEUJqmqiqrqnrs8OHFyRKi6fpSHJdGiVIs6rqOMW632+Vy+aGHHqpUKl\u002f72tdgup1n\u002fL+ket154oknfvazn73wwgtOs4kQMjOZQqFQqVRs24ao03eclw4dkmX57Nmz\u002f\u002fbf\u002flvLsnRdBxsuy\u002fLU1NRdd9316KOPep7H4lhSVdu2CSHtdjsJQyubDYJg3+9+d\u002fr06cnJyU996lNr1qyxbVsIYVlWLpdrNpsPPvjgr3\u002f96+PHj9cWFtauH2EdAkdWrVYbjcY3v\u002fnN8fHxz372syMja+fnFyAqYoxpqh4EwSOPPPK9733v8OHD7UYDYdzf32+a5tzcXLvROLh\u002f\u002f4ULF1566aWPfexj7373ja+GyCtULBYlSQoCD1hKKQ3DMJ\u002fPE0JA\u002fZaUECEkhOjr68vldM55q9FAhEgS0TStr7en1XB03ThzZizwfcM0z46dHRoa\u002fsxn\u002fkSWFbgdsMg5l2VZVbXnnnvu+eeek5AgAiOBGUZc0TVJlsNWS1FVTdMopUmSNptNSVUtyxocHLzooosuvvjilStXZrNZQohpWAsLC0899dT+\u002fft93w+CYGpq6uzZs3\u002f3d3+3NCRMemn2cPFHUqPROHny5MGDB51mUzUMSK\u002fa7fbw8 ...

# %% [markdown]
# Extraction of the license plates with the coordinates the model found

# %%
# extract text from image
text = pt.image_to_string(roi)
print(text)
# Out:
# B 2228 HN

# %% [markdown]
# Extract text from the picture

# %%
from sklearn.metrics import f1_score, precision_score, recall_score

# %% [markdown]
# Performance evaluation with measurements of the f1_score

# %%
from sklearn.metrics import f1_score, precision_score, recall_score

# Make predictions
y_pred = model.predict(x_test)
# Out:
# 3/3 [==============================] - 0s 183ms/step

# %%
# Convert predicted coordinates to actual bounding boxes
denorm = np.array([w, w, h, h])
y_pred_denorm = y_pred * denorm
y_pred_denorm = y_pred_denorm.astype(np.int32)

# %%
# Convert ground truth coordinates to actual bounding boxes
y_true_denorm = y_test * denorm
y_true_denorm = y_true_denorm.astype(np.int32)

# %%
# Flatten the arrays for f1_score calculation
y_true_flat = y_true_denorm.flatten()
y_pred_flat = y_pred_denorm.flatten()

# %%
# Apply a threshold (adjust as needed)
threshold = 0.5
y_pred_flat_binary = (y_pred_flat > threshold).astype(int)

# %%
# Calculate F1 score, precision, and recall
f1 = f1_score(y_true_flat, y_pred_flat_binary, average='micro')
precision = precision_score(y_true_flat, y_pred_flat_binary, average='micro')
recall = recall_score(y_true_flat, y_pred_flat_binary, average='micro')

# %%
print(f'F1 Score: {f1}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')
# Out:
# F1 Score: 0.0
# Precision: 0.0
# Recall: 0.0
